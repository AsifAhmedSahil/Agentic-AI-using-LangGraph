# %% [markdown]
# # essay evaluation workflow:
# START -> (clarity of thoughts, Depth of analysis, language quality) -> all 3 gives 2 things (1/score ,2/ text feedback) -> go to final evaluation node. aikhane last 3 ta theke asha info nia summary generate krbe allm, then average kroe final output dibe - final average score -> END

# %% [markdown]
# aikhane 3 ta jinish lagbe - parallel workflows, structured output, reducer function

# %%
from langgraph.graph import StateGraph,START,END
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
from typing import TypedDict
from pydantic import BaseModel,Field

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI(model='gpt-4o-mini')

# %%
class EvaluationSchema(BaseModel):
    feedback: str = Field(description="Detailed feedback for the essay")
    score : int = Field(description="Score out of 10", ge=0,le=10)

# %%
structure_model = model.with_structured_output(EvaluationSchema)

# %%
essay = '''**The Rise of AI in Bangladesh**

Artificial Intelligence (AI) is rapidly transforming Bangladesh and creating new opportunities in various sectors. With the growth of digital technology, businesses, educational institutions, and government organizations are increasingly adopting AI-based solutions to improve efficiency and productivity.

In the business sector, AI is being used for customer service, data analysis, fraud detection, and automation. Many startups and technology companies are developing AI-powered applications to solve local challenges. The banking and financial sectors are also using AI to enhance security and detect suspicious transactions.

Education is another area where AI is making a significant impact. Students now have access to intelligent learning tools, online tutors, and personalized educational resources. Universities are introducing courses related to AI, machine learning, and data science to prepare the next generation of professionals.

The government of Bangladesh is promoting digital transformation through various initiatives under the vision of a Smart Bangladesh. These efforts encourage innovation and create opportunities for AI research and development.

Despite its benefits, AI also presents challenges such as job displacement, data privacy concerns, and the need for skilled professionals. Therefore, proper policies, education, and ethical guidelines are essential for the responsible use of AI.

In conclusion, the rise of AI in Bangladesh is opening new possibilities for economic growth, innovation, and social development. With continued investment in technology and education, AI can play a vital role in shaping the country's future.
'''

# %%
class EssayState(TypedDict):
    essay:str
    language_feedback:str
    analysis_feedback:str
    clarity_feedback:str
    language_score:float
    analysis_score:float
    clarity_score:float
    overall_feedback:str
    indivisual_scores:list[int]
    avg_score:float

# %%
def evaluate_language(state:EssayState):
    prompt = f"Evaluate the language quality of the following essay and provide a feedback and assign the summary. {state['essay']}"
    output = structure_model.invoke(prompt)
    return {"language_feedback":output.feedback,"language_score":output.score}

# %%
def evaluate_analysis(state:EssayState):
    prompt = f"Evaluate the depth of analysis of the following essay and provide a feedback and assign the summary. {state['essay']}"
    output = structure_model.invoke(prompt)
    return {"analysis_feedback":output.feedback,"analysis_score":output.score}

# %%
def evaluate_thought(state:EssayState):
    prompt = f"Evaluate the clarity of thought of the following essay and provide a feedback and assign the summary. {state['essay']}"
    output = structure_model.invoke(prompt)
    return {"clarity_feedback":output.feedback,"clarity_score":output.score}

# %%
def final_evaluation(state:EssayState):
    prompt = f"based on the folowing feedback  create a summarized feedback \n language feedback - {state['language_feedback']} \n depth of asnalysis feedback - {state['analysis_feedback']} \n clarity of thought feedback - {state['clarity_feedback']} "
    overall_feedback = model.invoke(prompt).content

    indivisual_scores = [state['language_score'], state['analysis_score'], state['clarity_score']]
    avg_score = sum(indivisual_scores) / len(indivisual_scores)
     
    return {'overall_feedback':overall_feedback, "indivisual_scores":indivisual_scores, "avg_score":avg_score}

# %%
graph = StateGraph(EssayState)

graph.add_node('evaluate_language',evaluate_language)
graph.add_node('evaluate_analysis',evaluate_analysis)
graph.add_node('evaluate_thought',evaluate_thought)
graph.add_node('final_evaluation',final_evaluation)

# edges
graph.add_edge(START,'evaluate_language')
graph.add_edge(START,'evaluate_analysis')
graph.add_edge(START,'evaluate_thought')

graph.add_edge('evaluate_language','final_evaluation')
graph.add_edge('evaluate_analysis','final_evaluation')
graph.add_edge('evaluate_thought','final_evaluation')
graph.add_edge('final_evaluation',END)

workflow = graph.compile()

# %%
initial_state = {
    'essay':essay
}
workflow.invoke(initial_state)
# Out:
# {'essay': "**The Rise of AI in Bangladesh**\n\nArtificial Intelligence (AI) is rapidly transforming Bangladesh and creating new opportunities in various sectors. With the growth of digital technology, businesses, educational institutions, and government organizations are increasingly adopting AI-based solutions to improve efficiency and productivity.\n\nIn the business sector, AI is being used for customer service, data analysis, fraud detection, and automation. Many startups and technology companies are developing AI-powered applications to solve local challenges. The banking and financial sectors are also using AI to enhance security and detect suspicious transactions.\n\nEducation is another area where AI is making a significant impact. Students now have access to intelligent learning tools, online tutors, and personalized educational resources. Universities are introducing courses related to AI, machine learning, and data science to prepare the next generation of professionals.\n\nThe government of Bangladesh is promoting digital transformation through various initiatives under the vision of a Smart Bangladesh. These efforts encourage innovation and create opportunities for AI research and development.\n\nDespite its benefits, AI also presents challenges such as job displacement, data privacy concerns, and the need for skilled professionals. Therefore, proper policies, education, and ethical guidelines are essential for the responsible use of AI.\n\nIn conclusion, the rise of AI in Bangladesh is opening new possibilities for economic growth, innovation, and social development. With continued investment in technology and education, AI can play a vital role in shaping the country's future.\n",
#  'language_feedback': 'The essay presents a clear and coherent discussion of the rise of AI in Bangladesh, outlining its impact across various sectors, including business, education, and government. The language is primarily formal and appropriate for an academic or informative context, with a good structure that includes an introduction, body paragraphs, and a conclusion. However, there are a few areas where the language quality could be improved:\n\n1. **Sentence Variety**: While the language is clear, the sentence structure tends to be repetitive. Varying sentence length and complexity could enhance the essay\'s overall engagement.\n2. **Depth of Analysis**: The sections discussing challenges such as job displacement and data privacy could benefit from further elaboration, possibly including examples or statistics to support the claims. This would add depth to the analysis and provide a more rounded view of AI\'s impact.\n3. **Word Choice**: Some phrases could be rephrased for greater impact or clarity. For instance, replacing "creating new opportunities in various sectors" with "unlocking unprecedented opportunities across multiple sectors" might enhance the expression.\n4. **Transition Phrases**: Adding transitional phrases between sections could improve the flow of the essay, guiding the reader more smoothly through the argument.\n5. **Technical Details**: The discussion would benefit from a few specific examples of AI applications or companies in Bangladesh, which would lend credibility and context to the points made.\n\nOverall, the essay is well-structured and conveys the overall message effectively, but refining the above aspects would greatly enhance its language quality and depth of content.',
#  'analysis_feedback': "The essay provides a solid overview of the impact of AI in Bangladesh across various sectors, including business, education, and government. It highlights the potential benefits while also acknowledging the challenges that come with AI adoption, such as job displacement and the need for ethical considerations. However, the depth of analysis could be improved by including specific examples, statistics, or case studies to support claims made about AI's effectiveness and implications. Moreover, a discussion on the specific challenges faced in Bangladesh, such as infrastructure issues or governmental policies regarding AI, could further enhance the essay's depth. Overall, the ideas are presented clearly but would benefit from further elaboration and critical insight.",
#  'clarity_feedback': "The essay presents a clear and coherent overview of the rise of AI in Bangladesh, effectively outlining its impacts across various sectors such as business, education, and government. The structure is logical and follows a sequential flow from discussing the benefits to addressing the challenges posed by AI, which aids in clarity of thought. However, the essay could benefit from more specific examples or statistics to substantiate claims about AI's transformative effects. Additionally, elaborating on the challenges with concrete instances could deepen the analysis. Overall, the ideas are presented clearly, though further development of some points would enhance the essay's impact.",
#  'language_score': 7,
#  'analysis_score': 7,
#  'clarity_score': 8,
#  'overall_feedback': '**Summarized Feedback:**\n\nThe essay effectively discusses the rise of AI in Bangladesh, covering its implications across business, education, and government sectors. It is well-structured with a clear introduction, body, and conclusion, utilizing formal language suitable for an academic context. However, there are several areas for improvement:\n\n1. **Sentence Variation**: The sentence structure is somewhat repetitive; varying lengths and complexities would increase engagement.\n2. **Depth of Analysis**: The essay touches on challenges like job displacement and data privacy but lacks detailed examples or statistics to support these claims. Incorporating specific challenges faced in Bangladesh, such as infrastructure and governmental policies, would enhance depth.\n3. **Word Choice**: Some phrases could be rephrased for clarity and impact, e.g., using "unlocking unprecedented opportunities" instead of "creating new opportunities."\n4. **Transitions**: Introducing transitional phrases between sections could improve flow and guide the reader through the argument more effectively.\n5. **Technical Details**: Including examples of AI applications and companies in Bangladesh would add credibility and context to the discussion.\n\nOverall, while the essay presents its ideas clearly and logically, refining these aspects would greatly bolster its language quality and analytical depth.',
#  'indivisual_scores': [7, 7, 8],
#  'avg_score': 7.333333333333333}
